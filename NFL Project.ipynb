# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Possible ideas to explore
#
# -How well do certain defensive packages do against certin offensive packages
#
# -How well do certain defensive packages do in certain yardages situations
#
# -Can you predict how well a player does based on his physical stats, might need to bring in combine data
#
# -Can you predict which DB's will excel or struggle in man coverage based upon physical stats
#
# -try a group by function on the data frame, maybe

# %%
games = pd.read_csv('nfl-big-data-bowl-2021\games.csv', index_col = 'gameId')
players =pd.read_csv('nfl-big-data-bowl-2021\players.csv', index_col = 'nflId')
plays =pd.read_csv('nfl-big-data-bowl-2021\plays.csv', index_col = ['gameId', 'playId'])
week1 = pd.read_csv('nfl-big-data-bowl-2021\week1.csv')

# %%
week1[(week1['playId']== 75) & (week1['gameId'] == 2018090600) & (week1['event'] == 'pass_outcome_caught')]
# Out:
#                          time      x      y     s      a   dis       o  \
# 714  2018-09-07T01:07:19.700Z  96.10  27.82  0.99   1.14  0.10  327.40
# 715  2018-09-07T01:07:19.700Z  81.74  49.08  7.94   2.37  0.80    0.01
# 716  2018-09-07T01:07:19.700Z  81.48  50.13  4.93   3.07  0.49  326.77
# 717  2018-09-07T01:07:19.700Z  81.41  19.08  4.65   2.84  0.46  355.18
# 718  2018-09-07T01:07:19.700Z  76.75  36.60  2.82   1.85  0.28   33.31
# 719  2018-09-07T01:07:19.700Z  71.81  37.93  6.57   1.61  0.66   21.37
# 720  2018-09-07T01:07:19.700Z  89.30  30.99  3.60   1.45  0.37  293.03
# 721  2018-09-07T01:07:19.700Z  81.51  39.01  5.58   0.92  0.56  348.97
# 722  2018-09-07T01:07:19.700Z  76.54  14.86  4.91   1.36  0.49  249.15
# 723  2018-09-07T01:07:19.700Z  75.30  49.33  5.31   1.22  0.53   57.98
# 724  2018-09-07T01:07:19.700Z  77.70  13.31  6.73   2.22  0.68  137.26
# 725  2018-09-07T01:07:19.700Z  79.25  34.33  6.73   0.58  0.67  356.66
# ...

# %%
week1[(week1['event'] == 'pass_outcome_caught')|(week1['event'] == 'pass_outcome_incomplete')| (week1['event'] == 'pass_outcome_interception') | (week1['event'] == 'qb_sack') | (week1['event'] == 'qb_strip_sack')]
# Out:
#                             time      x      y     s     a   dis       o  \
# 714     2018-09-07T01:07:19.700Z  96.10  27.82  0.99  1.14  0.10  327.40
# 715     2018-09-07T01:07:19.700Z  81.74  49.08  7.94  2.37  0.80    0.01
# 716     2018-09-07T01:07:19.700Z  81.48  50.13  4.93  3.07  0.49  326.77
# 717     2018-09-07T01:07:19.700Z  81.41  19.08  4.65  2.84  0.46  355.18
# 718     2018-09-07T01:07:19.700Z  76.75  36.60  2.82  1.85  0.28   33.31
# ...                          ...    ...    ...   ...   ...   ...     ...
# 985672  2018-09-11T05:29:37.599Z  35.04  33.26  6.40  0.89  0.65   30.23
# 985673  2018-09-11T05:29:37.599Z  37.14  42.82  2.60  2.31  0.27   74.36
# 985674  2018-09-11T05:29:37.599Z  40.93  44.07  3.78  2.97  0.36  228.37
# 985675  2018-09-11T05:29:37.599Z  32.91  40.02  4.54  1.35  0.46   68.97
# 985676  2018-09-11T05:29:37.599Z  40.75  44.00  3.28  1.79  0.33     NaN
#
#            dir                event      nflId       displayName  \
# ...

# %%
week1[(week1['playId']== 3392) & (week1['gameId'] == 2018090600)]['event'].unique()
# Out:
# array(['None', 'ball_snap', 'pass_forward', 'pass_arrived',
#        'pass_outcome_interception', 'out_of_bounds'], dtype=object)

# %%
plays.loc[(2018090600, 3392), 'playDescription']
# Out:
# '(13:03) (Shotgun) M.Ryan pass short left intended for J.Jones INTERCEPTED by R.Douglas at PHI 4. R.Douglas ran ob at PHI 4 for no gain.'

# %%
for x in week1[week1['gameId'] == 2018090600]['event'].unique():
    print(x)
# Out:
# None
# ball_snap
# pass_forward
# pass_arrived
# pass_outcome_caught
# out_of_bounds
# pass_outcome_incomplete
# first_contact
# tackle
# man_in_motion
# play_action
# qb_sack
# fumble
# fumble_offense_recovered
# handoff
# pass_tipped
# pass_outcome_interception
# qb_strip_sack
# pass_shovel
# line_set

# %%
plays.head(5)
# Out:
#                                                      playDescription  quarter  \
# gameId     playId
# 2018090600 75      (15:00) M.Ryan pass short right to J.Jones pus...        1
#            146     (13:10) M.Ryan pass incomplete short right to ...        1
#            168     (13:05) (Shotgun) M.Ryan pass incomplete short...        1
#            190     (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1
#            256     (10:59) (Shotgun) M.Ryan pass incomplete short...        1
#
#                    down  yardsToGo possessionTeam        playType  \
# gameId     playId
# 2018090600 75         1         15            ATL  play_type_pass
#            146        1         10            ATL  play_type_pass
#            168        2         10            ATL  play_type_pass
#            190        3         10            ATL  play_type_pass
#            256        3          1            ATL  play_type_pass
#
# ...

# %%
plays.loc[(2018090901, 339), 'playDescription']
plays.loc[(2018090900, 2223), 'playDescription']
plays['personnelD']
# Out:
# gameId      playId
# 2018090600  75        4 DL, 2 LB, 5 DB
#             146       4 DL, 2 LB, 5 DB
#             168       4 DL, 2 LB, 5 DB
#             190       4 DL, 1 LB, 6 DB
#             256       6 DL, 3 LB, 2 DB
#                             ...
# 2018122200  2300      2 DL, 4 LB, 5 DB
#             3177      2 DL, 4 LB, 5 DB
# 2018122201  566       1 DL, 5 LB, 5 DB
#             1719      2 DL, 3 LB, 6 DB
#             2649      4 DL, 1 LB, 6 DB
# Name: personnelD, Length: 19239, dtype: object

# %%
week1[(week1['gameId'] == 2018090600) & (week1['playId'] == 3392) & (week1['event'] == 'pass_outcome_interception')]
# Out:
#                            time      x      y     s     a   dis       o  \
# 56442  2018-09-07T03:37:32.900Z  35.53  26.76  3.33  2.13  0.32  187.41
# 56443  2018-09-07T03:37:32.900Z  30.30  30.04  1.93  0.80  0.19  238.34
# 56444  2018-09-07T03:37:32.900Z  11.20   1.48  3.54  4.26  0.35  118.22
# 56445  2018-09-07T03:37:32.900Z  19.92  23.90  5.16  2.63  0.51  134.15
# 56446  2018-09-07T03:37:32.900Z  21.19  28.26  1.13  1.06  0.12  127.78
# 56447  2018-09-07T03:37:32.900Z  33.69  32.01  0.42  1.05  0.04  222.06
# 56448  2018-09-07T03:37:32.900Z  35.07  30.84  1.08  0.59  0.10  354.11
# 56449  2018-09-07T03:37:32.900Z  32.84  30.56  1.66  2.47  0.15  218.27
# 56450  2018-09-07T03:37:32.900Z   7.75  43.95  0.68  4.08  0.09  226.02
# 56451  2018-09-07T03:37:32.900Z   7.23  46.56  2.55  3.43  0.27  252.41
# 56452  2018-09-07T03:37:32.900Z  19.53  19.51  2.39  3.89  0.26  255.19
# 56453  2018-09-07T03:37:32.900Z  14.01   0.55  5.42  2.87  0.55   84.95
# ...

# %%
def defensive_player(gameid, playid):
    des = plays.loc[(gameid, playid), 'playDescription']
    in_1 = des.find('(', 10)
    in_2 = des.find(')', in_1)
    comma = des.find(',', in_1)
    if in_1 == -1 or in_2 == -1:
        result = 'N/A'
    elif 'sacked' in des:
        result = 'Overturned Strip Sack'
    else:
        if comma == -1 or comma > in_2:
            result = des[in_1+1:in_2]
            if 'thrown' in result:
                return 'N/A'
            elif ';' in result:
                result = []
                result.append(des[in_1+1:des.find(':', in_1)])
                result.append(des[des.find(':', in_1)+1:in_2])
        else:
            result = []
            result.append(des[in_1+1:comma])
            result.append(des[comma+2:in_2])
    return result
defensive_player(2018120902, 1864)

#Only works on incomplete passes at the minute
# Out:
# 'Overturned Strip Sack'

# %%
def dist(pos1, pos2):
    val = math.sqrt((pos1[0]-pos2[0])**2 + (pos1[1]-pos2[1])**2)
    return val

def separation(week, gameid, playid, team = 'both'):
    offense = ['QB', 'RB', 'FB', 'WR', 'TE', 'HB']
    defense = ['SS','FS', 'MLB', 'CB', 'LB', 'OLB', 'ILB', 'DL', 'DB', 'NT', 'S', 'DE']
    if team == 'both':
        players = offense + defense
    elif team =='offense':
        players = offense
    elif team == 'defense':
        players = defense
    else:
        return 'Enter {}, {},  or {}'.format('offense', 'defense', 'both')
    dist_to_ball = {}
    football = week[(week['playId']== playid) & (week['gameId'] == gameid) & (week['displayName'] == 'Football')  & ((week['event'] == 'pass_outcome_caught')|(week['event'] == 'pass_outcome_incomplete')| (week['event'] == 'pass_outcome_interception') | (week['event'] == 'qb_sack') | (week['event'] == 'qb_strip_sack'))]
    ball_pos = football.loc[:, ['x']]['x'].item(), football.loc[:, ['y']]['y'].item()
    for x in players:
        for index, row in week[(week['playId']== playid) & (week['gameId'] == gameid) & (week['displayName'] != 'Football') & (week['position'] == x) & ((week['event'] == 'pass_outcome_caught')|(week['event'] == 'pass_outcome_incomplete')| (week['event'] == 'pass_outcome_interception') | (week['event'] == 'qb_sack') | (week['event'] == 'qb_strip_sack'))].iterrows():
            player_name = row['displayName']
            player_pos = row['x'], row['y']
            distance = dist(ball_pos, player_pos)
            dist_to_ball[player_name] = distance
    lowest_dist = 100
    lowest_name = ''  
    for key, value in dist_to_ball.items():
        if value < lowest_dist:
            lowest_dist = value
            lowest_name = key
    return lowest_name, lowest_dist#, week['event']
#print(separation(week1, 2018090600, 75, 'defense'))

def nearest_receiver(week, gameid, playid):
    answer = separation(week, gameid, playid, 'offense')
    return answer
def nearest_defender(week, gameid, playid):
    answer =separation(week, gameid, playid, 'defense')
    return answer
print(nearest_defender(week1, 2018090600, 75))
print(nearest_receiver(week1, 2018090600, 75))
# Out:
# ('Malcolm Jenkins', 1.81339460680791, 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 986017    None
# 986018    None
# 986019    None
# 986020    None
# 986021    None
# Name: event, Length: 986022, dtype: object)
# ('Julio Jones', 0.7510659092250156, 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 986017    None
# 986018    None
# 986019    None
# 986020    None
# 986021    None
# Name: event, Length: 986022, dtype: object)

# %%
for x in week1[week1['gameId'] == 2018090600]['playId'].unique():
    print(nearest_defender(week1, 2018090600, x), x)
# Out:
# ('Malcolm Jenkins', 1.81339460680791) 75
# ('Jordan Hicks', 3.2020618357552046) 146
# ('Sidney Jones', 3.722633476451852) 168
# ('Ronald Darby', 0.8646964785403056) 190
# ('Malcolm Jenkins', 1.424113759500973) 256
# ('Robert Alford', 1.216963434126103) 320
# ('Ricardo Allen', 3.4063470169670027) 344
# ('Ronald Darby', 1.246194206373949) 402
# ('Jordan Hicks', 6.590371764931019) 492
# ('Nate Gerry', 2.182292372712694) 521
# ('Ronald Darby', 4.206019495912971) 545
# ('Ronald Darby', 0.702566722810011) 636
# ('Robert Alford', 0.9042676594902634) 752
# ('Brian Poole', 0.6428063471995287) 776
# ('Vic Beasley', 9.432120652324164) 839
# ('Rodney McLeod', 1.6172198366332249) 889
# ('Corey Graham', 13.499703700452097) 949
# ("De'Vondre Campbell", 2.7901612856607434) 992
# ('Robert Alford', 0.6420280367709796) 1037
# ('Robert Alford', 0.880567998510055) 1061
# ('Brian Poole', 3.7444892842682833) 1085
# ('Deion Jones', 1.0621205204683697) 1202
# ('Desmond Trufant', 0.8297590011563613) 1226
# ...

# %%
incomplete_plays = plays[plays['passResult']=='C']
for x in incomplete_plays.index:
    gameid = x[0]
    playid = x[1]
    #if len(defensive_player(gameid, playid)) >10:
    print(x[0], x[1])
    print(defensive_player(gameid, playid))

# %%
week1.head(20)

# %%
week1[(week1['gameId'] == 2018090600) & (week1['playId'] == 75) & (week1['event'] != 'None')].head(50)
